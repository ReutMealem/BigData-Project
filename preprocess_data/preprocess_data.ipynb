# %%
import psycopg2
import pandas as pd
import vaex
import ast 
import numpy as np
import pickle
import os
from joblib import Parallel, delayed
import os
import sys

# %%
base_dir = 'base_dir'
code_dir = os.path.join(base_dir, 'code')
sys.path.append(code_dir)
import const
import params

# %% [markdown]
# #### Read OpenAlex data Clean the data and remain only important columns

# %%
# Path to the Parquet file
file_path = os.path.join(const.data_base_dir, "OpenAlex_merged_data.parquet")

# Read the Parquet file into a Vaex dataframe
df = vaex.open(file_path)
df.head(5)
# Out:
#   #  work_id                           author_id                         institution_id                      publication_year  publication_date      cited_by_count  author_name       institution_name                                     country_code
#   0  https://openalex.org/W3126688306  https://openalex.org/A5021130645  https://openalex.org/I2799504677                2009  2009-12-31                         0  Carbonne Pierre   "Institut de l'Audiovisuel et des Télécommunicat...  FR
#   1  https://openalex.org/W3126688306  https://openalex.org/A5030528300  https://openalex.org/I2799504677                2009  2009-12-31                         0  Thomas Hain       "Institut de l'Audiovisuel et des Télécommunicat...  FR
#   2  https://openalex.org/W3126688306  https://openalex.org/A5038081513  https://openalex.org/I190778170                 2009  2009-12-31                         0  Gary Clemo        Ofcom                                                GB
#   3  https://openalex.org/W3126688432  https://openalex.org/A5082259378  https://openalex.org/I130701412                 2020  2020-12-23                         0  Віра Борщовецька  Chernivtsi National University                       UA
#   4  https://openalex.org/W3126688432  https://openalex.org/A5045080228  https://openalex.org/I130701412                 2020  2020-12-23                         0  Марія Рубанець    Chernivtsi National University                       UA

# %%
# Filter out rows with 'publication_year' between 2023 and 2025
author_data = df[(df['publication_year'] < 2023)]

# Select only the required columns
columns_to_keep = ['author_id','author_name', 'publication_year', 'institution_name' ,'country_code']
author_data_cleaned = author_data[columns_to_keep]

# %%
# Get the shape of the DataFrame
num_rows = len(author_data_cleaned)  # Number of rows
num_columns = len(author_data_cleaned.get_column_names())  # Number of columns

# Print the shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 343450875
# Number of columns: 5

# %%
# Chunk size (10 million rows)
chunk_size = 1000000
authors_output_dir = const.author_dir
os.makedirs(authors_output_dir, exist_ok=True)

# Split and save the dataframe in chunks
for i in range(0, len(df), chunk_size):
    chunk = df[i:i + chunk_size]
    output_file = os.path.join(authors_output_dir, f"chunk_{i // chunk_size + 1}.parquet")
    chunk.export_parquet(output_file)
    print(f"Saved chunk {i // chunk_size + 1} to {output_file}")

# %%
author_data_cleaned.head(5)

# %% [markdown]
# #### Read war data

# %%
merged_wars_data_file = os.path.join(const.data_base_dir, "merged_war_data_after_expand.csv")
war_data = pd.read_csv(merged_wars_data_file)

# %%
war_data.head(5)
# Out:
#    Year Country Code  Min_Year       Date      War Name  \
# 0  1939           US      1939  1939–1945  World War II
# 1  1939           SU      1939  1939–1945  World War II
# 2  1939           GB      1939  1939–1945  World War II
# 3  1939           CN      1939  1939–1945  World War II
# 4  1939           FR      1939  1939–1945  World War II
#
#                       Combatants Location  \
# 0  Allied Powers vs. Axis Powers   Global
# 1  Allied Powers vs. Axis Powers   Global
# 2  Allied Powers vs. Axis Powers   Global
# 3  Allied Powers vs. Axis Powers   Global
# 4  Allied Powers vs. Axis Powers   Global
#
#                               Countries Participants
# 0  United States, Soviet Union, United Kingdom, C...
# 1  United States, Soviet Union, United Kingdom, C...
# 2  United States, Soviet Union, United Kingdom, C...
# 3  United States, Soviet Union, United Kingdom, C...
# 4  United States, Soviet Union, United Kingdom, C...

# %%
war_data_unique = war_data.drop_duplicates(subset=["Year", "Country Code"])
war_lookup = war_data_unique.set_index(["Year", "Country Code"]).to_dict(orient="index")

# %% [markdown]
# #### Add the war information to openAlex data

# %%
# Group data by publication_year and process each group
unique_years = author_data_cleaned.unique("publication_year")
print(unique_years)

for year in unique_years:
    print(f"Processing year: {year}")
    
    # Filter the data for the current year
    year_data = author_data_cleaned[author_data_cleaned["publication_year"] == year]
    print(len(year_data))

# %%
# Define a function to process chunks
def process_chunk_pandas(chunk, war_lookup):
    # Apply the filter for publication_year < 2023
    # chunk = chunk[chunk["publication_year"] < 2023]
    print("Add war exist")
    # Vectorized lookup for war information
    chunk["war_exist"] = chunk.apply(
        lambda row: 1 if (row["publication_year"], row["country_code"]) in war_lookup else 0,
        axis=1
    )
    
    print("Add year in war")
    chunk["year_in_war"] = chunk.apply(
        lambda row: row["publication_year"] - war_lookup.get((row["publication_year"], row["country_code"]), {}).get("Min_Year", None)
        if (row["publication_year"], row["country_code"]) in war_lookup else 0,
        axis=1
    )
    
    print("Add war name")
    chunk["war_name"] = chunk.apply(
        lambda row: war_lookup.get((row["publication_year"], row["country_code"]), {}).get("War Name", "No War")
        if (row["publication_year"], row["country_code"]) in war_lookup else "No War",
        axis=1
    )

    return chunk

# %%
def main(task_id):
    print(f"Start load and processing war data")
    merged_wars_data_file = os.path.join(const.data_base_dir, "merged_war_data_after_expand.csv")
    war_data = pd.read_csv(merged_wars_data_file)
    war_data_unique = war_data.drop_duplicates(subset=["Year", "Country Code"])
    columns_to_drop = ["Date", "Combatants", "Location", "Countries Participants"]
    war_data_unique = war_data_unique.drop(columns=columns_to_drop)

    # Create war lookup dictionary
    war_lookup = {
        (row["Year"], row["Country Code"]): {"Min_Year": row["Year"], "War Name": row["War Name"]}
        for _, row in war_data_unique.iterrows()
    }
    print(f"Finish load and processing war data")

    print(f"Start load and processing author data")
    # Load author data
    author_file_path = os.path.join(const.data_base_dir, "OpenAlex_merged_data.parquet")
    df = vaex.open(author_file_path, transform=True)
    author_data_cleaned = df[df["publication_year"] < 2023]
    columns_to_keep = ['author_name', 'publication_year', 'institution_name', 'country_code']
    author_data_cleaned = author_data_cleaned[columns_to_keep]

    print(f"Finish load and processing author data")

    # Process data for the specific year
    year = params.years_dict[task_id]
    print(f"Processing year {year}")
    chunk = params.get_year_df(author_data_cleaned, task_id)  # Get chunk for the specific year

    chunk = chunk.to_pandas_df()
    # Process the chunk
    processed_chunk = process_chunk_pandas(chunk, war_lookup)

    # Drop NaN values
    processed_chunk = processed_chunk.dropna()
    num_rows = len(processed_chunk)  # Number of rows
    # Print the shape
    print(f"Number of rows: {num_rows}")

    # Directory to save processed Parquet files
    output_dir = os.path.join(const.data_base_dir,"processed_chunks_combine_war_openalex")
    os.makedirs(output_dir, exist_ok=True)

    # Save processed chunk to Parquet
    output_file = os.path.join(output_dir, f"year_{year}.pkl")
    processed_chunk.to_pickle(output_file)

    # processed_chunk.export_parquet(output_file)
    print(f"Finished processing year {year} and saved to {output_file}")

if __name__ == "__main__":
    # for task_id in range(1,73):
    task_id = int(sys.argv[1])
    main(task_id)
# Out:
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1951
# Add war exist
# Add year in war
# Add war name
# Number of rows: 66775
# Finished processing year 1951 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1951.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1952
# Add war exist
# Add year in war
# Add war name
# Number of rows: 70577
# Finished processing year 1952 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1952.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1953
# Add war exist
# Add year in war
# Add war name
# Number of rows: 76799
# Finished processing year 1953 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1953.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1954
# Add war exist
# Add year in war
# Add war name
# Number of rows: 83300
# Finished processing year 1954 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1954.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1955
# Add war exist
# Add year in war
# Add war name
# Number of rows: 90343
# Finished processing year 1955 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1955.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1956
# Add war exist
# Add year in war
# Add war name
# Number of rows: 99340
# Finished processing year 1956 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1956.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1957
# Add war exist
# Add year in war
# Add war name
# Number of rows: 105777
# Finished processing year 1957 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1957.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1958
# Add war exist
# Add year in war
# Add war name
# Number of rows: 117285
# Finished processing year 1958 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1958.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1959
# Add war exist
# Add year in war
# Add war name
# Number of rows: 132058
# Finished processing year 1959 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1959.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1960
# Add war exist
# Add year in war
# Add war name
# Number of rows: 147872
# Finished processing year 1960 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1960.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1961
# Add war exist
# Add year in war
# Add war name
# Number of rows: 153690
# Finished processing year 1961 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1961.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1962
# Add war exist
# Add year in war
# Add war name
# Number of rows: 173408
# Finished processing year 1962 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1962.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1963
# Add war exist
# Add year in war
# Add war name
# Number of rows: 192775
# Finished processing year 1963 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1963.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1964
# Add war exist
# Add year in war
# Add war name
# Number of rows: 217973
# Finished processing year 1964 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1964.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1965
# Add war exist
# Add year in war
# Add war name
# Number of rows: 245338
# Finished processing year 1965 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1965.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1966
# Add war exist
# Add year in war
# Add war name
# Number of rows: 272593
# Finished processing year 1966 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1966.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1967
# Add war exist
# Add year in war
# Add war name
# Number of rows: 302789
# Finished processing year 1967 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1967.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1968
# Add war exist
# Add year in war
# Add war name
# Number of rows: 334819
# Finished processing year 1968 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1968.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1969
# Add war exist
# Add year in war
# Add war name
# Number of rows: 367784
# Finished processing year 1969 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1969.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1970
# Add war exist
# Add year in war
# Add war name
# Number of rows: 440088
# Finished processing year 1970 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1970.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1971
# Add war exist
# Add year in war
# Add war name
# Number of rows: 429683
# Finished processing year 1971 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1971.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1972
# Add war exist
# Add year in war
# Add war name
# Number of rows: 472637
# Finished processing year 1972 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1972.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1973
# Add war exist
# Add year in war
# Add war name
# Number of rows: 516310
# Finished processing year 1973 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1973.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1974
# Add war exist
# Add year in war
# Add war name
# Number of rows: 541613
# Finished processing year 1974 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1974.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1975
# Add war exist
# Add year in war
# Add war name
# Number of rows: 547171
# Finished processing year 1975 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1975.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1976
# Add war exist
# Add year in war
# Add war name
# Number of rows: 595724
# Finished processing year 1976 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1976.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1977
# Add war exist
# Add year in war
# Add war name
# Number of rows: 650639
# Finished processing year 1977 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1977.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1978
# Add war exist
# Add year in war
# Add war name
# Number of rows: 711652
# Finished processing year 1978 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1978.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1979
# Add war exist
# Add year in war
# Add war name
# Number of rows: 750020
# Finished processing year 1979 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1979.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1980
# Add war exist
# Add year in war
# Add war name
# Number of rows: 814718
# Finished processing year 1980 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1980.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1981
# Add war exist
# Add year in war
# Add war name
# Number of rows: 901799
# Finished processing year 1981 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1981.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1982
# Add war exist
# Add year in war
# Add war name
# Number of rows: 929798
# Finished processing year 1982 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1982.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1983
# Add war exist
# Add year in war
# Add war name
# Number of rows: 995747
# Finished processing year 1983 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1983.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1984
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1088934
# Finished processing year 1984 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1984.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1985
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1168081
# Finished processing year 1985 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1985.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1986
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1242405
# Finished processing year 1986 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1986.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1987
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1466248
# Finished processing year 1987 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1987.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1988
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1641110
# Finished processing year 1988 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1988.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1989
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1769942
# Finished processing year 1989 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1989.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1990
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1929958
# Finished processing year 1990 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1990.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1991
# Add war exist
# Add year in war
# Add war name
# Number of rows: 1992330
# Finished processing year 1991 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1991.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1992
# Add war exist
# Add year in war
# Add war name
# Number of rows: 2124068
# Finished processing year 1992 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1992.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1993
# Add war exist
# Add year in war
# Add war name
# Number of rows: 2283767
# Finished processing year 1993 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1993.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1994
# Add war exist
# Add year in war
# Add war name
# Number of rows: 2426040
# Finished processing year 1994 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1994.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1995
# Add war exist
# Add year in war
# Add war name
# Number of rows: 2585174
# Finished processing year 1995 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1995.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1996
# Add war exist
# Add year in war
# Add war name
# Number of rows: 2905768
# Finished processing year 1996 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1996.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1997
# Add war exist
# Add year in war
# Add war name
# Number of rows: 3072626
# Finished processing year 1997 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1997.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1998
# Add war exist
# Add year in war
# Add war name
# Number of rows: 3291134
# Finished processing year 1998 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1998.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 1999
# Add war exist
# Add year in war
# Add war name
# Number of rows: 3471570
# Finished processing year 1999 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_1999.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2000
# Add war exist
# Add year in war
# Add war name
# Number of rows: 3763328
# Finished processing year 2000 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2000.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2001
# Add war exist
# Add year in war
# Add war name
# Number of rows: 3998854
# Finished processing year 2001 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2001.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2002
# Add war exist
# Add year in war
# Add war name
# Number of rows: 4764877
# Finished processing year 2002 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2002.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2003
# Add war exist
# Add year in war
# Add war name
# Number of rows: 5109164
# Finished processing year 2003 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2003.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2004
# Add war exist
# Add year in war
# Add war name
# Number of rows: 5727684
# Finished processing year 2004 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2004.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2005
# Add war exist
# Add year in war
# Add war name
# Number of rows: 6322755
# Finished processing year 2005 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2005.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2006
# Add war exist
# Add year in war
# Add war name
# Number of rows: 7311640
# Finished processing year 2006 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2006.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2007
# Add war exist
# Add year in war
# Add war name
# Number of rows: 7901936
# Finished processing year 2007 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2007.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2008
# Add war exist
# Add year in war
# Add war name
# Number of rows: 8504577
# Finished processing year 2008 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2008.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2009
# Add war exist
# Add year in war
# Add war name
# Number of rows: 9484561
# Finished processing year 2009 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2009.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2010
# Add war exist
# Add year in war
# Add war name
# Number of rows: 10870511
# Finished processing year 2010 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2010.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2011
# Add war exist
# Add year in war
# Add war name
# Number of rows: 11230683
# Finished processing year 2011 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2011.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2012
# Add war exist
# Add year in war
# Add war name
# Number of rows: 12313776
# Finished processing year 2012 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2012.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2013
# Add war exist
# Add year in war
# Add war name
# Number of rows: 13502262
# Finished processing year 2013 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2013.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2014
# Add war exist
# Add year in war
# Add war name
# Number of rows: 14679967
# Finished processing year 2014 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2014.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2015
# Add war exist
# Add year in war
# Add war name
# Number of rows: 15736238
# Finished processing year 2015 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2015.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2016
# Add war exist
# Add year in war
# Add war name
# Number of rows: 16920328
# Finished processing year 2016 and saved to /home/reutme/Big_data/final_project/data/processed_chunks_combine_war_openalex/year_2016.pkl
# Start load and processing war data
# Finish load and processing war data
# Start load and processing author data
# Finish load and processing author data
# Processing year 2017
# Add war exist
# Add year in war
